# %% [markdown]
# # backtrader - 지정가 주문 다루기
#
# backtrader를 사용해서 지정가 주문을 다루는 예제코드입니다.
# 아래 내용들을 다루고 있습니다.
# - 지정가 주문 제출
# - 조건부 지정가 주문 제출
# - 미체결 주문 조회
# - 정정 주문 및 취소 주문 제출

# %% [markdown]
# ### 주문 유형
#
# backtrader에는 다음의 주문 유형이 정의되어 있습니다.
# - `Order.Market`: 시장가 주문 (기본값)
# - `Order.Limit`: 지정가 주문
# - `Order.Stop`: 지정된 가격에 도달했을 때 시장가 주문 제출
# - `Order.StopLimit`: 지정된 가격에 도달했을 때 `pricelimit`으로 지정된 가격으로 지정가 주문 제출
#
#
# `valid` 파라미터와 조합하여 주문의 유효기간을 설정할 수 있습니다.
# - `None`: 취소할 때까지 주문이 계속 살아있음. 국내 시장의 경우 지원하지 않는 유형. (기본값)
# - `datetime.datetime` or `datetime.date`: 지정할 날짜까지 주문이 계속 살아있음. 마찬가지로 국내 시장의 경우 거래일이 넘어갈 때까지 남아있는 주문 유형은 없음
# - `Order.DAY` or `0` or timedelta(): 당일 장 마감시간 까지 유효
# - 숫자값: matplotlib coding에서 x축의 해당하는 시간값을 의미.
#
#
# 국내 시장에서 제공되는 주문유형인 조건부 지정가(장 마감시까지 체결이 안된 경우 시장가로 체결)는 제공되지 않으므로 주의해야 합니다. 또한 지정가 주문을 사용하는 경우 valid 파라미터는 항상 `Order.DAY`로 사용해야 합니다.

# %% [markdown]
# ### 지정가 주문 제출
#
# 지정가 주문을 체결될 수 없는 가격 제출 (현재 타임라인의 저가보다 10틱아래)에 제출하여 미체결 상태로 장 종료 시점 까지 남아있는 경우를 만들었습니다.
# - buy(price=가격, exectype=지정가, valid=오늘한정, size=매수수량)
# - get_order_open() - 미체결 주문 조회
# - getposition(data) - 보유포지션 조회

# %%
import backtrader as bt
import datetime as dtm
from pyqqq.data.minutes import get_all_day_data
from pyqqq.utils.compute import get_krx_tick_size

class St(bt.Strategy):
    last_trade_id = 1

    params = {
        'short_period': 30,
        'long_period': 120,
    }

    def __init__(self):
        # 지표는 __init__에서 선언해야 함
        self.short_ma = bt.indicators.SimpleMovingAverage(self.data.close, period=self.params.short_period)
        self.long_ma = bt.indicators.SimpleMovingAverage(self.data.close, period=self.params.long_period)
        self.last_trade_id = 1

    def log(self, s):
        # 현재 시간은 self.data.datetime 으로 접근가능
        dt = self.data.datetime.datetime()
        print(f"{dt.isoformat()}: {s}")

    def next(self):
        # self.log(f"open={self.data.open[0]} high={self.data.high[0]} low={self.data.low[0]} close={self.data.close[0]} volume={self.data.volume[0]}")

        position = self.broker.getposition(data=self.data)
        if position:
            self.log(f"Position size={position.size} price={position.price} value={position.size*position.price}")

        pending_orders = self.broker.get_orders_open()
        for order in pending_orders:
            self.log(f"[Pending Order] {order.data._name} size={order.size} price={order.price} tradeid={order.tradeid}")

        if self.short_ma > self.long_ma and len(pending_orders) == 0:
            tick = get_krx_tick_size(self.data.close[0], etf_etn=False)
            target_price = self.data.low[0] - tick*10

            self.buy(price=target_price, exectype=bt.Order.Limit, valid=bt.Order.DAY, size=1, tradeid=self.last_trade_id)
            self.last_trade_id += 1
            self.log(f"Send buy order at {target_price}")

        elif self.short_ma < self.long_ma and position.size > 0:
            self.sell()

    def notify_order(self, order):
        exectypes = ['Market', 'Close', 'Limit', 'Stop', 'StopLimit', 'StopTrail', 'StopTrailLimit', 'Historical']
        statuses =  ['Created', 'Submitted', 'Accepted', 'Partial', 'Completed', 'Canceled', 'Expired', 'Margin', 'Rejected']

        self.log(f"[{'Buy' if order.isbuy() else 'Sell'} Order] {order.data._name} size={order.size} exectype={exectypes[order.exectype]} price={order.price} status={statuses[order.status]} tradeid={order.tradeid} current_price={self.data.low[0]}")


asset_code = '005930'
target_date = dtm.datetime.today() - dtm.timedelta(days=1)
dfs = get_all_day_data(target_date.date(), [asset_code])
df = dfs[asset_code]

cerebro = bt.Cerebro()

cerebro.adddata(bt.feeds.PandasData(dataname=df), name=asset_code)
initial_cash = 10_000_000
cerebro.broker.setcash(initial_cash)
cerebro.addstrategy(St)

cerebro.run()

print(f"Initial Portfolio Value: {initial_cash}")
print(f"Final Portfolio Value: {cerebro.broker.getvalue()}")
# Out:
# 2024-05-22T10:59:00: Send buy order at 77400.0
# 2024-05-22T11:00:00: [Buy Order] 005930 size=1 exectype=Limit price=77400.0 status=Submitted tradeid=1 current_price=78400.0
# 2024-05-22T11:00:00: [Buy Order] 005930 size=1 exectype=Limit price=77400.0 status=Accepted tradeid=1 current_price=78400.0
# 2024-05-22T11:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:20:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:21:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:22:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:23:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:24:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:25:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:26:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:27:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:28:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:29:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:30:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:31:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:32:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:33:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:34:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:35:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:36:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:37:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:38:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:39:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:40:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:41:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:42:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:43:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:44:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:45:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:46:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:47:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:48:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:49:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:50:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:51:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:52:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:53:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:54:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:55:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:56:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:57:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:58:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:59:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:20:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:21:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:22:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:23:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:24:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:25:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:26:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:27:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:28:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:29:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:30:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:31:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:32:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:33:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:34:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:35:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:36:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:37:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:38:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:39:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:40:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:41:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:42:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:43:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:44:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:45:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:46:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:47:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:48:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:49:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:50:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:51:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:52:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:53:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:54:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:55:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:56:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:57:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:58:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:59:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:20:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:21:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:22:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:23:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:24:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:25:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:26:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:27:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:28:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:29:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:30:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:31:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:32:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:33:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:34:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:35:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:36:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:37:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:38:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:39:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:40:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:41:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:42:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:43:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:44:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:45:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:46:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:47:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:48:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:49:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:50:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:51:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:52:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:53:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:54:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:55:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:56:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:57:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:58:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:59:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:20:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:21:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:22:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:23:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:24:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:25:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:26:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:27:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:28:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:29:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:30:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:31:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:32:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:33:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:34:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:35:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:36:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:37:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:38:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:39:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:40:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:41:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:42:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:43:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:44:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:45:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:46:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:47:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:48:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:49:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:50:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:51:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:52:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:53:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:54:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:55:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:56:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:57:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:58:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:59:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:29:00: Market closed at 15:29:00
# Initial Portfolio Value: 10000000
# Final Portfolio Value: 10000000.0

# %% [markdown]
# ### 지정가 - 취소주문, 정정주문
#
# backtrader는 정정주문을 지원하지 않습니다. 정정주문을 하려면, 기존 주문을 취소하고 새로운 주문을 내려야 합니다.
# - self.broker.getposition(data): 보유포지션 조회
# - self.get_orders_open(): 미체결 주문 조회
# - self.cancel(order): 미체결 주문 쥐소

# %%
import datetime as dtm
from pyqqq.data.minutes import get_all_day_data

class St(bt.Strategy):
    last_trade_id = 1

    params = {
        'short_period': 30,
        'long_period': 120,
    }

    def __init__(self):
        # 지표는 __init__에서 선언해야 함
        self.short_ma = bt.indicators.SimpleMovingAverage(self.data.close, period=self.params.short_period)
        self.long_ma = bt.indicators.SimpleMovingAverage(self.data.close, period=self.params.long_period)
        self.last_trade_id = 1

    def log(self, s):
        # 현재 시간은 self.data.datetime 으로 접근가능
        dt = self.data.datetime.datetime()
        print(f"{dt.isoformat()}: {s}")

    def next(self):
        position = self.broker.getposition(data=self.data)
        if position:
            self.log(f"Position size={position.size} price={position.price} value={position.size*position.price}")

        pending_orders = self.broker.get_orders_open()
        for order in pending_orders:
            self.log(f"[Pending Order] {order.data._name} size={order.size} price={order.price} tradeid={order.tradeid}")

        # Golden cross 상황에 포지션 없으면 매수 주문
        if self.short_ma > self.long_ma and not position:
            if len(pending_orders) == 0:
                # 주문이 없으면 체결될 수 없는 낮은 가격으로 매수 주문
                tick = get_krx_tick_size(self.data.close[0], etf_etn=False)
                target_price = self.data.low[0] - tick*10

                self.buy(price=target_price, exectype=bt.Order.Limit, valid=bt.Order.DAY, size=1, tradeid=self.last_trade_id)
                self.last_trade_id += 1
                self.log(f"Send buy order at {target_price}")
            else:
                # 기존 주문을 취소하고 체결 될 수 있는 고가로 새로 주문 제출
                order = pending_orders[0]
                self.cancel(order)

                self.buy(price=self.data.low[0], exectype=bt.Order.Limit, valid=bt.Order.DAY, size=1, tradeid=self.last_trade_id)
                self.last_trade_id += 1
                self.log(f"Cancel previous order and send new buy order at {self.data.low[0]}")



        elif self.short_ma < self.long_ma and position.size > 0:
            self.sell()


    def notify_order(self, order):
        exectypes = ['Market', 'Close', 'Limit', 'Stop', 'StopLimit', 'StopTrail', 'StopTrailLimit', 'Historical']
        statuses =  ['Created', 'Submitted', 'Accepted', 'Partial', 'Completed', 'Canceled', 'Expired', 'Margin', 'Rejected']

        self.log(f"[{'Buy' if order.isbuy() else 'Sell'} Order] {order.data._name} size={order.size} exectype={exectypes[order.exectype]} price={order.price} status={statuses[order.status]} tradeid={order.tradeid} current_price={self.data.low[0]}")


asset_code = '005930'
target_date = dtm.datetime.today() - dtm.timedelta(days=1)
dfs = get_all_day_data(target_date.date(), [asset_code])
df = dfs[asset_code]

cerebro = bt.Cerebro()

cerebro.adddata(bt.feeds.PandasData(dataname=df), name=asset_code)
initial_cash = 10_000_000
cerebro.broker.setcash(initial_cash)
cerebro.addstrategy(St)

cerebro.run()

print(f"Initial Portfolio Value: {initial_cash}")
print(f"Final Portfolio Value: {cerebro.broker.getvalue()}")
# Out:
# 2024-05-22T10:59:00: Send buy order at 77400.0
# 2024-05-22T11:00:00: [Buy Order] 005930 size=1 exectype=Limit price=77400.0 status=Submitted tradeid=1 current_price=78400.0
# 2024-05-22T11:00:00: [Buy Order] 005930 size=1 exectype=Limit price=77400.0 status=Accepted tradeid=1 current_price=78400.0
# 2024-05-22T11:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:00:00: Cancel previous order and send new buy order at 78400.0
# 2024-05-22T11:01:00: [Buy Order] 005930 size=1 exectype=Limit price=77400.0 status=Canceled tradeid=1 current_price=78400.0
# 2024-05-22T11:01:00: [Buy Order] 005930 size=1 exectype=Limit price=78400.0 status=Submitted tradeid=2 current_price=78400.0
# 2024-05-22T11:01:00: [Buy Order] 005930 size=1 exectype=Limit price=78400.0 status=Accepted tradeid=2 current_price=78400.0
# 2024-05-22T11:01:00: [Buy Order] 005930 size=1 exectype=Limit price=78400.0 status=Completed tradeid=2 current_price=78400.0
# 2024-05-22T11:01:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:02:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:03:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:04:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:05:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:06:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:07:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:08:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:09:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:10:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:11:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:12:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:13:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:14:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:15:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:16:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:17:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:18:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:19:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:20:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:21:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:22:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:23:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:24:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:25:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:26:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:27:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:28:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:29:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:30:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:31:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:32:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:33:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:34:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:35:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:36:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:37:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:38:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:39:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:40:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:41:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:42:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:43:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:44:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:45:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:46:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:47:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:48:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:49:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:50:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:51:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:52:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:53:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:54:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:55:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:56:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:57:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:58:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T11:59:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:00:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:01:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:02:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:03:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:04:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:05:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:06:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:07:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:08:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:09:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:10:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:11:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:12:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:13:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:14:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:15:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:16:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:17:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:18:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:19:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:20:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:21:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:22:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:23:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:24:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:25:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:26:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:27:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:28:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:29:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:30:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:31:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:32:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:33:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:34:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:35:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:36:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:37:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:38:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:39:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:40:00: Position size=1 price=78400.0 value=78400.0
# 2024-05-22T12:41:00: [Sell Order] 005930 size=-1 exectype=Market price=None status=Submitted tradeid=0 current_price=78300.0
# 2024-05-22T12:41:00: [Sell Order] 005930 size=-1 exectype=Market price=None status=Accepted tradeid=0 current_price=78300.0
# 2024-05-22T12:41:00: [Sell Order] 005930 size=-1 exectype=Market price=None status=Completed tradeid=0 current_price=78300.0
# Initial Portfolio Value: 10000000
# Final Portfolio Value: 9999900.0

# %% [markdown]
# ### 조건부 지정가
#
# 조건부 지정가 방식도 backtrader에 존재하지 않습니다.
# 지정가 주문에 대한 미체결주문이 동시호가시간에 남아 있는 경우 취소하고 종가로 제출하여 같은 효과를 구현할 수 있습니다.

# %%
import datetime as dtm
from pyqqq.data.minutes import get_all_day_data

class St(bt.Strategy):
    last_trade_id = 1

    params = {
        'short_period': 30,
        'long_period': 120,
    }

    def __init__(self):
        # 지표는 __init__에서 선언해야 함
        self.short_ma = bt.indicators.SimpleMovingAverage(self.data.close, period=self.params.short_period)
        self.long_ma = bt.indicators.SimpleMovingAverage(self.data.close, period=self.params.long_period)
        self.last_trade_id = 1

    def log(self, s):
        # 현재 시간은 self.data.datetime 으로 접근가능
        dt = self.data.datetime.datetime()
        print(f"{dt.isoformat()}: {s}")

    def next(self):
        position = self.broker.getposition(data=self.data)
        if position:
            self.log(f"Position size={position.size} price={position.price} value={position.size*position.price}")

        pending_orders = self.broker.get_orders_open()
        for order in pending_orders:
            self.log(f"[Pending Order] {order.data._name} size={order.size} price={order.price} tradeid={order.tradeid}")

        # Golden cross 상황에 포지션 없으면 매수 주문
        if self.short_ma > self.long_ma and not position:
            if len(pending_orders) == 0:
                # 주문이 없으면 체결될 수 없는 낮은 가격으로 매수 주문
                tick = get_krx_tick_size(self.data.close[0], etf_etn=False)
                target_price = self.data.low[0] - tick*10

                self.buy(price=target_price, exectype=bt.Order.Limit, valid=bt.Order.DAY, size=1, tradeid=self.last_trade_id)
                self.last_trade_id += 1
                self.log(f"Send buy order at {target_price}")



        current_time = self.data.datetime.time()

        if len(pending_orders) > 0 and current_time.hour == 15 and current_time.minute == 19:
            for order in pending_orders:
                self.cancel(order)
                self.log(f"Cancel and make new market order {order.tradeid}")
                self.buy(tradeid=self.last_trade_id, size=1, exectype=bt.Order.Close)
                self.last_trade_id += 1

    def notify_order(self, order):
        exectypes = ['Market', 'Close', 'Limit', 'Stop', 'StopLimit', 'StopTrail', 'StopTrailLimit', 'Historical']
        statuses =  ['Created', 'Submitted', 'Accepted', 'Partial', 'Completed', 'Canceled', 'Expired', 'Margin', 'Rejected']

        self.log(f"[{'Buy' if order.isbuy() else 'Sell'} Order] {order.data._name} size={order.size} exectype={exectypes[order.exectype]} price={order.price} status={statuses[order.status]} tradeid={order.tradeid} current_price={self.data.low[0]}")


asset_code = '005930'
target_date = dtm.datetime.today() - dtm.timedelta(days=1)
dfs = get_all_day_data(target_date.date(), [asset_code])
df = dfs[asset_code]

cerebro = bt.Cerebro()

cerebro.adddata(bt.feeds.PandasData(dataname=df), name=asset_code)
initial_cash = 10_000_000
cerebro.broker.setcash(initial_cash)
cerebro.addstrategy(St)

cerebro.run()

print(f"Initial Portfolio Value: {initial_cash}")
print(f"Final Portfolio Value: {cerebro.broker.getvalue()}")
# Out:
# 2024-05-22T10:59:00: Send buy order at 77400.0
# 2024-05-22T11:00:00: [Buy Order] 005930 size=1 exectype=Limit price=77400.0 status=Submitted tradeid=1 current_price=78400.0
# 2024-05-22T11:00:00: [Buy Order] 005930 size=1 exectype=Limit price=77400.0 status=Accepted tradeid=1 current_price=78400.0
# 2024-05-22T11:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:20:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:21:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:22:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:23:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:24:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:25:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:26:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:27:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:28:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:29:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:30:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:31:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:32:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:33:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:34:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:35:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:36:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:37:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:38:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:39:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:40:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:41:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:42:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:43:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:44:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:45:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:46:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:47:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:48:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:49:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:50:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:51:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:52:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:53:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:54:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:55:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:56:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:57:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:58:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T11:59:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:20:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:21:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:22:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:23:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:24:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:25:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:26:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:27:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:28:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:29:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:30:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:31:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:32:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:33:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:34:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:35:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:36:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:37:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:38:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:39:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:40:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:41:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:42:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:43:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:44:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:45:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:46:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:47:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:48:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:49:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:50:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:51:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:52:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:53:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:54:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:55:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:56:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:57:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:58:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T12:59:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:20:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:21:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:22:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:23:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:24:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:25:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:26:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:27:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:28:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:29:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:30:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:31:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:32:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:33:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:34:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:35:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:36:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:37:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:38:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:39:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:40:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:41:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:42:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:43:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:44:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:45:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:46:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:47:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:48:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:49:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:50:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:51:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:52:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:53:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:54:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:55:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:56:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:57:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:58:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T13:59:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:20:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:21:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:22:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:23:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:24:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:25:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:26:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:27:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:28:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:29:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:30:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:31:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:32:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:33:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:34:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:35:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:36:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:37:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:38:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:39:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:40:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:41:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:42:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:43:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:44:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:45:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:46:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:47:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:48:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:49:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:50:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:51:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:52:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:53:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:54:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:55:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:56:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:57:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:58:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T14:59:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:00:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:01:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:02:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:03:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:04:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:05:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:06:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:07:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:08:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:09:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:10:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:11:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:12:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:13:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:14:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:15:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:16:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:17:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:18:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:19:00: [Pending Order] 005930 size=1 price=77400.0 tradeid=1
# 2024-05-22T15:19:00: Cancel and make new market order 1
# 2024-05-22T15:29:00: [Buy Order] 005930 size=1 exectype=Limit price=77400.0 status=Canceled tradeid=1 current_price=77700.0
# 2024-05-22T15:29:00: [Buy Order] 005930 size=1 exectype=Close price=None status=Submitted tradeid=2 current_price=77700.0
# 2024-05-22T15:29:00: [Buy Order] 005930 size=1 exectype=Close price=None status=Accepted tradeid=2 current_price=77700.0
# 2024-05-22T15:29:00: [Pending Order] 005930 size=1 price=None tradeid=2
# Initial Portfolio Value: 10000000
# Final Portfolio Value: 10000000.0
